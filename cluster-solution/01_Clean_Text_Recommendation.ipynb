# %% [markdown]
# In this notebook we first extracted table of contents. Then by using table of contents as guides, we separeted the whole reports into artitcles. Since we are only interested in Recommendation sections, Recommendation reports are selected. There are many customized search for different years of reports. The final output of this notebook is a table with all the recommendations by years. Rare special characters are removed. Spells are corrected.

# %%
# %pip install --upgrade pip
# !pip install -r ..\requirements.txt
# Out:
# Requirement already satisfied: pip in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (23.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: absl-py in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: antlr4-python3-runtime in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 2)) (4.9.3)
# Requirement already satisfied: anyio in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 3)) (3.6.2)
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Requirement already satisfied: astor in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 6)) (0.8.1)
# Requirement already satisfied: attrs in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 7)) (22.2.0)
# Requirement already satisfied: backcall in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 9)) (4.12.1)
# Requirement already satisfied: bitarray in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 10)) (2.7.3)
# Requirement already satisfied: bleach in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 11)) (6.0.0)
# Requirement already satisfied: blis in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 12)) (0.7.9)
# Requirement already satisfied: catalogue in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 13)) (2.0.8)
# Requirement already satisfied: certifi in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 14)) (2022.12.7)
# Requirement already satisfied: cffi in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 15)) (1.15.1)
# Requirement already satisfied: charset-normalizer in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 16)) (3.1.0)
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: colorama in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 18)) (0.4.6)
# Collecting confection
#   Using cached confection-0.0.4-py3-none-any.whl (32 kB)
# Collecting cryptography
#   Using cached cryptography-40.0.1-cp36-abi3-win_amd64.whl (2.6 MB)
# Requirement already satisfied: cycler in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 21)) (0.11.0)
# Requirement already satisfied: cymem in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 22)) (2.0.7)
# Requirement already satisfied: Cython in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 23)) (0.29.28)
# Requirement already satisfied: debugpy in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 24)) (1.6.7)
# Requirement already satisfied: decorator in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 25)) (5.1.1)
# Requirement already satisfied: defusedxml in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 26)) (0.7.1)
# Requirement already satisfied: editdistpy in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 27)) (0.1.3)
# Requirement already satisfied: entrypoints in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 28)) (0.4)
# Requirement already satisfied: fastjsonschema in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 29)) (2.16.3)
# Requirement already satisfied: filelock in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 30)) (3.11.0)
# Requirement already satisfied: fonttools in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 31)) (4.38.0)
# Requirement already satisfied: gast in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 32)) (0.4.0)
# Collecting gensim
#   Using cached gensim-4.2.0-cp37-cp37m-win_amd64.whl (24.0 MB)
# Requirement already satisfied: google-pasta in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 34)) (0.2.0)
# Requirement already satisfied: grpcio in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 35)) (1.53.0)
# Requirement already satisfied: h5py in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 36)) (3.8.0)
# Collecting huggingface-hub
#   Using cached huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
# Collecting hydra-core
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Requirement already satisfied: idna in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 39)) (3.4)
# Requirement already satisfied: importlib-metadata in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 40)) (6.1.0)
# Requirement already satisfied: importlib-resources in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 41)) (5.12.0)
# Requirement already satisfied: ipykernel in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 42)) (6.16.2)
# Requirement already satisfied: ipython in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 43)) (7.34.0)
# Requirement already satisfied: ipython-genutils in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 44)) (0.2.0)
# Collecting ipywidgets
#   Using cached ipywidgets-8.0.6-py3-none-any.whl (138 kB)
# Requirement already satisfied: jedi in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 46)) (0.18.2)
# Requirement already satisfied: Jinja2 in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 47)) (3.1.2)
# Requirement already satisfied: joblib in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 48)) (1.2.0)
# Collecting jsonschema
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting jupyter-console
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting jupyter-server
#   Using cached jupyter_server-1.23.6-py3-none-any.whl (347 kB)
# Requirement already satisfied: jupyter_client in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 53)) (7.4.9)
# Requirement already satisfied: jupyter_core in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 54)) (4.12.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 55)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 56)) (3.0.7)
# Collecting Keras-Applications
#   Using cached Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Requirement already satisfied: Keras-Preprocessing in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 58)) (1.1.2)
# Requirement already satisfied: kiwisolver in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 59)) (1.4.4)
# Requirement already satisfied: langcodes in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 60)) (3.3.0)
# Requirement already satisfied: lxml in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 61)) (4.9.2)
# Collecting Markdown
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Requirement already satisfied: MarkupSafe in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 63)) (2.1.2)
# Collecting matplotlib
#   Using cached matplotlib-3.5.3-cp37-cp37m-win_amd64.whl (7.2 MB)
# Requirement already satisfied: matplotlib-inline in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 65)) (0.1.6)
# Requirement already satisfied: mistune in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 66)) (2.0.5)
# Requirement already satisfied: murmurhash in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 67)) (1.0.9)
# Collecting nbclassic
#   Using cached nbclassic-0.5.5-py3-none-any.whl (10.0 MB)
# Collecting nbclient
#   Using cached nbclient-0.7.3-py3-none-any.whl (72 kB)
# Collecting nbconvert
#   Using cached nbconvert-7.3.0-py3-none-any.whl (284 kB)
# Collecting nbformat
#   Using cached nbformat-5.8.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: nest-asyncio in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 72)) (1.5.6)
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting notebook
#   Using cached notebook-6.5.4-py3-none-any.whl (529 kB)
# Collecting notebook_shim
#   Using cached notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 76)) (1.21.6)
# Requirement already satisfied: omegaconf in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 77)) (2.3.0)
# Requirement already satisfied: opt-einsum in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 78)) (3.3.0)
# Requirement already satisfied: packaging in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 79)) (23.0)
# Collecting pandas
#   Using cached pandas-1.3.5-cp37-cp37m-win_amd64.whl (10.0 MB)
# Requirement already satisfied: pandocfilters in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 81)) (1.5.0)
# Requirement already satisfied: parso in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 82)) (0.8.3)
# Collecting pathy
#   Using cached pathy-0.10.1-py3-none-any.whl (48 kB)
# Requirement already satisfied: pexpect in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 84)) (4.8.0)
# Requirement already satisfied: pickleshare in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 85)) (0.7.5)
# Requirement already satisfied: Pillow in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 86)) (9.5.0)
# Requirement already satisfied: pkgutil_resolve_name in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 87)) (1.3.10)
# Requirement already satisfied: plotly in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 88)) (5.14.1)
# Requirement already satisfied: portalocker in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 89)) (2.7.0)
# Requirement already satisfied: preshed in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 90)) (3.0.8)
# Requirement already satisfied: prometheus-client in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 91)) (0.16.0)
# Requirement already satisfied: prompt-toolkit in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 92)) (3.0.38)
# Requirement already satisfied: protobuf in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 93)) (3.19.6)
# Requirement already satisfied: psutil in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 94)) (5.9.4)
# Requirement already satisfied: ptyprocess in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 95)) (0.7.0)
# Requirement already satisfied: pycparser in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 96)) (2.21)
# Requirement already satisfied: pydantic in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 97)) (1.10.7)
# Requirement already satisfied: Pygments in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 98)) (2.14.0)
# Collecting pyOpenSSL
#   Using cached pyOpenSSL-23.1.1-py3-none-any.whl (57 kB)
# Requirement already satisfied: pyparsing in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 100)) (3.0.9)
# Requirement already satisfied: pyrsistent in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 101)) (0.19.3)
# Requirement already satisfied: python-dateutil in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 102)) (2.8.2)
# Requirement already satisfied: pytz in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 103)) (2023.3)
# Requirement already satisfied: PyYAML in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 104)) (6.0)
# Requirement already satisfied: pyzmq in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 105)) (25.0.2)
# Collecting qtconsole
#   Using cached qtconsole-5.4.2-py3-none-any.whl (121 kB)
# Requirement already satisfied: QtPy in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 107)) (2.3.1)
# Requirement already satisfied: regex in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 108)) (2022.10.31)
# Requirement already satisfied: requests in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 109)) (2.28.2)
# Requirement already satisfied: sacrebleu in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 110)) (2.3.1)
# Requirement already satisfied: scikit-learn in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 111)) (1.0.2)
# Requirement already satisfied: scipy in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 112)) (1.7.3)
# Requirement already satisfied: Send2Trash in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 113)) (1.8.0)
# Collecting sentence-transformers
#   Using cached sentence-transformers-2.2.2.tar.gz (85 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: sentencepiece in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 115)) (0.1.97)
# Requirement already satisfied: six in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 116)) (1.16.0)
# Requirement already satisfied: smart-open in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 118)) (6.3.0)
# Requirement already satisfied: sniffio in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 119)) (1.3.0)
# Requirement already satisfied: soupsieve in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 120)) (2.4)
# Collecting spacy
#   Using cached spacy-3.5.1-cp37-cp37m-win_amd64.whl (12.5 MB)
# Requirement already satisfied: spacy-legacy in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 122)) (3.0.12)
# Requirement already satisfied: spacy-loggers in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 123)) (1.0.4)
# Requirement already satisfied: srsly in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 124)) (2.4.6)
# Requirement already satisfied: symspellpy in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 125)) (6.7.7)
# Requirement already satisfied: tabulate in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 126)) (0.9.0)
# Requirement already satisfied: tenacity in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 127)) (8.2.2)
# Collecting tensorboard
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# Requirement already satisfied: tensorboardX in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 129)) (2.6)
# Collecting tensorflow
#   Using cached tensorflow-2.11.0-cp37-cp37m-win_amd64.whl (1.9 kB)
# Requirement already satisfied: tensorflow-estimator in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 131)) (2.11.0)
# Requirement already satisfied: tensorflow-hub in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 132)) (0.13.0)
# Requirement already satisfied: termcolor in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 133)) (2.2.0)
# Requirement already satisfied: terminado in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 134)) (0.17.1)
# Collecting thinc
#   Using cached thinc-8.1.9-cp37-cp37m-win_amd64.whl (1.5 MB)
# Requirement already satisfied: threadpoolctl in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 136)) (3.1.0)
# Requirement already satisfied: tinycss2 in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 137)) (1.2.1)
# Requirement already satisfied: tokenizers in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 138)) (0.13.3)
# Requirement already satisfied: torch in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 139)) (1.13.1)
# Requirement already satisfied: torchvision in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 140)) (0.14.1)
# Requirement already satisfied: tornado in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 141)) (6.2)
# Requirement already satisfied: tqdm in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 142)) (4.65.0)
# Requirement already satisfied: traitlets in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 143)) (5.9.0)
# Collecting transformers
#   Using cached transformers-4.27.4-py3-none-any.whl (6.8 MB)
# Collecting typer
#   Using cached typer-0.7.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: typing_extensions in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 146)) (4.4.0)
# Requirement already satisfied: urllib3 in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 147)) (1.26.15)
# Requirement already satisfied: wasabi in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 148)) (1.1.1)
# Requirement already satisfied: wcwidth in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 149)) (0.2.6)
# Requirement already satisfied: webencodings in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 150)) (0.5.1)
# Requirement already satisfied: websocket-client in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 151)) (1.5.1)
# Requirement already satisfied: Werkzeug in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 152)) (2.2.3)
# Requirement already satisfied: widgetsnbextension in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 153)) (4.0.7)
# Requirement already satisfied: wrapt in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 154)) (1.15.0)
# Requirement already satisfied: zipp in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from -r ..\requirements.txt (line 155)) (3.15.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from ipython->-r ..\requirements.txt (line 43)) (47.1.0)
# Requirement already satisfied: pywinpty in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from jupyter-server->-r ..\requirements.txt (line 52)) (2.0.10)
# Requirement already satisfied: pywin32>=1.0 in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from jupyter_core->-r ..\requirements.txt (line 54)) (306)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: wheel>=0.26 in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from tensorboard->-r ..\requirements.txt (line 128)) (0.40.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from tensorboard->-r ..\requirements.txt (line 128)) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from tensorboard->-r ..\requirements.txt (line 128)) (2.17.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\administrator\desktop\project\cmv-commitee-rec-nlp\env\lib\site-packages (from tensorboard->-r ..\requirements.txt (line 128)) (1.8.1)
# Collecting tensorflow-intel==2.11.0
#   Using cached tensorflow_intel-2.11.0-cp37-cp37m-win_amd64.whl (266.3 MB)
# ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device

# %%
from symspellpy import SymSpell, Verbosity
sym_spell = SymSpell(max_dictionary_edit_distance=2, prefix_length=7)

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.data_clean_functions import *

# %%
import numpy as np
import pandas as pd
import re

# %%
# read CMV reports file 
# "CMV_Reports_Text.csv" file has PDF scaned CMV reports data
# "CMV_Report_Dates.csv" file has two columns. One column is Year, another column is the first page number of its corresponding year of report. It is used for labeling years to their corresponding articles.
reports = pd.read_csv('../CMV Reports Text.csv')
report_dates = pd.read_csv('../CMV_Report_Dates.csv')

# %%
report_dates.head()
# Out:
#    PageNumber  Year
# 0           1  1996
# 1          59  1997
# 2          82  1998
# 3         120  1999
# 4         148  2000

# %%
# create the pageNumber and Year for the last page of the report
lastrow = pd.DataFrame({'PageNumber': reports.sort_values('PageNumber').iloc[-1]['PageNumber'], 
                                                      'Year': report_dates.iloc[-1]['Year']}, index=[0])

# %%
report_dates = pd.concat([report_dates, lastrow]).reset_index(drop=True)

# %%
report_dates.tail()
# Out:
#     PageNumber  Year
# 24         842  2016
# 25         885  2017
# 26         926  2018
# 27         973  2020
# 28        1016  2020

# %%
# this function created PageNumber and Years for pages in between pages in report_dates table
def create_rows_between(report_dates):
    report_between = pd.DataFrame(columns = ['PageNumber', 'Year'])
    years  = []
    pagenums = []
    for i in range(1, len(report_dates)):
        between_n = report_dates['PageNumber'][i] - report_dates['PageNumber'][i-1] -1
        years.extend(np.repeat([report_dates['Year'][i-1]], between_n ))
        
        prev = report_dates['PageNumber'][i-1]
        for k in range(between_n):
            curr = prev + 1
            pagenums.append(curr)
            prev = curr
            
    report_between['Year'] = years 
    report_between['PageNumber'] = pagenums 
    
    return report_between
report_between = create_rows_between(report_dates)

# %%
report_between.head()
# Out:
#    PageNumber  Year
# 0           2  1996
# 1           3  1996
# 2           4  1996
# 3           5  1996
# 4           6  1996

# %%
report_between.tail()
# Out:
#      PageNumber  Year
# 982        1011  2020
# 983        1012  2020
# 984        1013  2020
# 985        1014  2020
# 986        1015  2020

# %%
# get all the pages and their year labels
report_dates = pd.concat([report_dates, report_between])
# merge report text with dates
reports = reports.merge(report_dates, how = 'outer').reset_index(drop=True)

# %%
reports.head()
# Out:
#    PageNumber                                         ReportText  \
# 0           1  Ne eae |\r\nTHE SECOND ANNUAL REPORT\r\n/ OF T...
# 1           2  is DEPARTMENT OF VETERANS AFFAIRS\r\ny “RY % a...
# 2           3  i a\r\nStatement of the Chairman, Advisory Com...
# 3           4  A great many people throughout the Congress of...
# 4           5  TABLE OF CONTENTS\r\nStatement of the Chairman...
#
#    IsTableOfContents  IsCoverPage  DocumentBegin  IsAttatchment  Year
# 0                  0            1              1              0  1996
# 1                  1            0              0              0  1996
# 2                  1            0              0              0  1996
# 3                  1            0              0              0  1996
# 4                  0            0              0              0  1996

# %%
# clean up text
reports['ReportText'] = [remove_extra_space(
    remove_rare_special_character(
        fix_typo(
            remove_lo(
                remove_vertical_line(
                    fix_roma_numbers(
                        remove_extra_dot(
                            remove_hyphen(
                                remove_colon(
                                    remove_quotes(
                                        replace_quotes(
                                            remove_bracket(
                                                normalize_week(
                                                    normalize_month(
                                                        normalize_year(
                                                            normalize_new_lines(
                                                                i.lower()
                                                            )
                                                        )
                                                    )
                                                )
                                            )
                                        )
                                    )
                                )
                            )
                        )
                    )
                )
            )
        )
    )
).strip() for i in reports['ReportText']]

# %%
# get the index of table of contents rows
TOC_idx = [i for i, s in enumerate(reports['ReportText']) if re.findall("TABLE OF CONTENTs?( ?)+(page)?\n".lower(), s ) ]

# %%
# there should be 23 "table of contents"
reports_TOC = reports.iloc[TOC_idx]
print(len(reports_TOC))
# Out:
# 21

# %%
# adding table of content page for 2016
reports_TOC = pd.concat([reports_TOC, reports[reports['PageNumber'] == 844]]).reset_index(drop=True)
# now we are only missing 2010 and 2019 which is true in the original doc

# %%
# add table of content manually for 2001
reports_TOC = pd.concat([reports_TOC, pd.DataFrame({'PageNumber':190,
'ReportText':'table of contents\nintroduction\ngeneral overview\nReport on the wilmington, de, meeting\ngeneral\nveterans entrepreneurship\nVeterans Entrepreneurship and Small Business Development\nWorkforce Diversity Plan\nGeneral\nSecretary Principis Comments\nVeterans Benefit Clearinghouse VBC \nVocational Rehabilitation & Employment Service\nServing Native American Veterans\nHepatitis C Treatment\nCenter for Minority Veterans\nCommittee Recommendations\nAppendix A\nAppendix B\nAdvisory Committee Agenda Continued\nAppendix C\n'.lower(),
'IsTableOfContents': 1,
'IsCoverPage': 0,
'DocumentBegin': 1,
'IsAttatchment': 0,
'Year': 2001}, index = [0])]).reset_index(drop=True)

# %%
len(reports_TOC)
# Out:
# 23

# %%
# reports' table of content
reports_TOC.head()
# Out:
#    PageNumber                                         ReportText  \
# 0           5  table of contents\nstatement of the chairman, ...
# 1          60  table of contents\npage\nstatement of the chai...
# 2          83  table of contents\npage\n\nchairmans transmitt...
# 3         121  table of contents\npage\nfifth annual report 1...
# 4         152  table of contents\n1 letter of transmittal\n2 ...
#
#    IsTableOfContents  IsCoverPage  DocumentBegin  IsAttatchment  Year
# 0                  0            0              0              0  1996
# 1                  1            0              0              0  1997
# 2                  1            0              0              0  1998
# 3                  1            0              0              0  1999
# 4                  1            0              0              0  2000

# %%
reports_TOC['IsTableOfContents1'] = 1
reports = reports.merge(reports_TOC[['PageNumber', 'IsTableOfContents1']], how = 'left').reset_index(drop=True)
import math
reports['IsTableOfContents1'] = [0 if math.isnan(i) else int(i) for i in reports['IsTableOfContents1']]

# %%
reports.head()
# Out:
#    PageNumber                                         ReportText  \
# 0           1  ne eae \nthe second annual report\n of the\nad...
# 1           2  is department of veterans affairs\ny ry a cent...
# 2           3  i a\nstatement of the chairman, advisory commi...
# 3           4  a great many people throughout the congress of...
# 4           5  table of contents\nstatement of the chairman, ...
#
#    IsTableOfContents  IsCoverPage  DocumentBegin  IsAttatchment  Year  \
# 0                  0            1              1              0  1996
# 1                  1            0              0              0  1996
# 2                  1            0              0              0  1996
# 3                  1            0              0              0  1996
# 4                  0            0              0              0  1996
#
#    IsTableOfContents1
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   1

# %%
# separate reports into articles based on table of contents
articleDF = pd.DataFrame(columns = ['Title', 'ArticleText', 'PageNumber'])
for k in range(len(reports_TOC)):
    articleDF = pd.concat([articleDF, separate_text_into_articles(reports, reports_TOC, k)])

# %%
articleDF.head()
# Out:
#                                                Title  \
# 0                                Begin of the report
# 1  statement of the chairman, advisory committee ...
# 2                                  executive summary
# 3                                       introduction
# 4                                            general
#
#                                          ArticleText    PageNumber
# 0  ne eae \nthe second annual report\n of the\nad...     [1, 2, 3]
# 1  \npursuant to section 510, public law 103 446,...  [3, 4, 5, 6]
# 2  \nthe second annual report of the advisory com...     [6, 7, 8]
# 3  \nthe committee conducted its last session, mo...           [8]
# 4  \nthe subcommittees based their pian on three ...        [8, 9]

# %%
# separate articles even more by "/n/n" which can be seen as the separation symbol for paragraphs
# first set unique id for each article
# regeneate index for articles
articleDF = articleDF.reset_index(drop = True)
# put index to column
articleDF = articleDF.reset_index(drop = False)
articleDF = articleDF.rename(columns = {'index': 'ArticleIndex'})

# %%
# add year column
articleDF['Year'] = [reports[reports['PageNumber'] == i[-1]]['Year'].tolist()[0] for i in articleDF['PageNumber']]

# %%
# select recommendations
recommd = articleDF[['recommendation' in i for i in articleDF['Title']]]

# %%
# check if I get all the recommdations from all years
recommd.Year.unique()
recommd = recommd.reset_index(drop = True)

# %%
recommd.head()
# Out:
#    ArticleIndex                                              Title  \
# 0             8                                    recommendations
# 1            23                                    recommendations
# 2            37                       statement of recommendations
# 3            39                                    recommendations
# 4            43  vas response to advisory committee recommendat...
#
#                                          ArticleText  \
# 0  based on the its research, collaboration, part...
# 1  the full committee recommends that the secreta...
# 2  \n1. the full committee recommends the secreta...
# 3  \n1. initiate a review of the funding and oper...
# 4  \n1. initiate a review of the funding and oper...
#
#                             PageNumber  Year
# 0                         [17, 18, 19]  1996
# 1         [67, 68, 69, 70, 71, 72, 73]  1997
# 2                             [94, 95]  1998
# 3                        [98, 99, 100]  1998
# 4  [113, 114, 115, 116, 117, 118, 119]  1998

# %%
# missing 2011, 2012, 2003
# there is no recommendation reports in 2003. But there are Issues mentioned there
# fixed 2011 in the raw csv file. table of content part I was scaned as part | ,and in the article it is scaned as l
# fixed 2012. It is similar case with 2011.
# since 2008, the format of recommendation change from "recommendations" only to "recommendations and va responses" to "recommendations, rationales and VA Responses"

# %%
# need to fix recommendations that are not captured correctly.
recommd = recommd[[('rationale' not in str(recommd['Title'][i])) or (recommd['Year'][i] in (2009, 2011, 2012)) for i in range(len(recommd)) ]]

# %%
# fix 2013
rec_strt = re.search('acmv year recommendations, rationales, and va responses', recommd[recommd['Year'] == 2013]['ArticleText'].tolist()[0]).span()[0]-13
recommd.loc[recommd['Year'] == 2013, 'ArticleText'] = recommd[recommd['Year'] == 2013]['ArticleText'].tolist()[0][:rec_strt]

# %%
# fix 2008
# index for recommendation
rec_idx = []
prev = 0
for i in re.finditer('recommendation \d+', recommd[recommd['Year'] == 2008]['ArticleText'].tolist()[0]):
    curr = int(re.findall('\d+', i.group(0))[0])
    if curr>prev:
        rec_idx.append(i.span()[0])
        prev = curr
# ignore the match that has occured before

# %%
len(rec_idx)
# Out:
# 22

# %%
# index for the start of other content other than recommendations
va_idx = []
prev = 0
for i in re.finditer('va response', recommd[recommd['Year'] == 2008]['ArticleText'].tolist()[0]):
    va_idx.append(i.span()[0])

# %%
len(va_idx)
# Out:
# 22

# %%
rec_str = []
recommd2008 = recommd[recommd['Year'] == 2008]['ArticleText'].tolist()[0]
for i in range(len(rec_idx)):
    rec_str.append(recommd2008[rec_idx[i]:va_idx[i]])

# %%
recommd.loc[recommd['Year'] == 2008, 'ArticleText'] = ''.join(rec_str)

# %%
# fix 2009
# index for recommendation
rec_idx = []
prev = 0
for i in re.finditer(r'\n\d+\. ', recommd[recommd['Year'] == 2009]['ArticleText'].tolist()[0]):
    curr = int(re.findall(r'\d+', i.group(0))[0])
    if curr>prev:
        rec_idx.append(i.span()[0])
        prev = curr
# ignore the match that has occured before

# index for the start of other content other than recommendations
va_idx = []
prev = 0
for i in re.finditer(r'\nrationale', recommd[recommd['Year'] == 2009]['ArticleText'].tolist()[0]):
    va_idx.append(i.span()[0])

# %%
len(rec_idx)
# Out:
# 14

# %%
len(va_idx)
# Out:
# 14

# %%
rec_str = []
recommd2009 = recommd[recommd['Year'] == 2009]['ArticleText'].tolist()[0]
for i in range(len(rec_idx)):
    rec_str.append(recommd2009[rec_idx[i]:va_idx[i]])

# %%
recommd.loc[recommd['Year'] == 2009, 'ArticleText'] = ''.join(rec_str)

# %%
# fix 2011
# index for recommendation
rec_idx = []
prev = 0
for i in re.finditer(r'\n\d+\. ', recommd[recommd['Year'] == 2011]['ArticleText'].tolist()[0]):
    curr = int(re.findall(r'\d+', i.group(0))[0])
    if curr>prev:
        rec_idx.append(i.span()[0])
        prev = curr
# ignore the match that has occured before

# index for the start of other content other than recommendations
va_idx = []
prev = 0
for i in re.finditer(r'\nrationale', recommd[recommd['Year'] == 2011]['ArticleText'].tolist()[0]):
    va_idx.append(i.span()[0])

# %%
print(len(rec_idx))
print(len(va_idx))
# Out:
# 13
# 13

# %%
rec_str = []
recommd2011 = recommd[recommd['Year'] == 2011]['ArticleText'].tolist()[0]
for i in range(len(rec_idx)):
    rec_str.append(recommd2011[rec_idx[i]:va_idx[i]])
    
recommd.loc[recommd['Year'] == 2011, 'ArticleText'] = ''.join(rec_str)

# %%
# fix 2012
# index for recommendation
rec_idx = []
prev = 0
for i in re.finditer(r'recommendation \d+ ', recommd[recommd['Year'] == 2012]['ArticleText'].tolist()[0]):
    curr = int(re.findall(r'\d+', i.group(0))[0])
    if curr>prev:
        rec_idx.append(i.span()[0])
        prev = curr
# ignore the match that has occured before

# index for the start of other content other than recommendations
va_idx = []
prev = 0
for i in re.finditer(r'\nrationale \d+ ', recommd[recommd['Year'] == 2012]['ArticleText'].tolist()[0]):
    va_idx.append(i.span()[0])

# %%
print(len(rec_idx))
print(len(va_idx))
# Out:
# 11
# 11

# %%
rec_str = []
recommd2012 = recommd[recommd['Year'] == 2012]['ArticleText'].tolist()[0]
for i in range(len(rec_idx)):
    rec_str.append(recommd2012[rec_idx[i]:va_idx[i]])
    
recommd.loc[recommd['Year'] == 2012, 'ArticleText'] = ''.join(rec_str)

# %%
# fix 2004
# index for recommendation
rec_idx = []
prev = 0
for i in re.finditer(r'recommendation \d+ ', recommd[recommd['Year'] == 2004]['ArticleText'].tolist()[0]):
    curr = int(re.findall(r'\d+', i.group(0))[0])
    if curr>prev:
        rec_idx.append(i.span()[0])
        prev = curr
# ignore the match that has occured before

# index for the start of other content other than recommendations
va_idx = []
prev = 0
for i in re.finditer(r'\nva response ', recommd[recommd['Year'] == 2004]['ArticleText'].tolist()[0]):
    va_idx.append(i.span()[0])

# %%
print(len(rec_idx))
print(len(va_idx))
# Out:
# 5
# 5

# %%
rec_str = []
recommd2004 = recommd[recommd['Year'] == 2004]['ArticleText'].tolist()[0]
for i in range(len(rec_idx)):
    rec_str.append(recommd2004[rec_idx[i]:va_idx[i]])
    
recommd.loc[recommd['Year'] == 2004, 'ArticleText'] = ''.join(rec_str)

# %%
# fix 2007
# index for recommendation
rec_idx = []
prev = 0
for i in re.finditer(r'recommendation \d+ ', recommd[recommd['Year'] == 2007]['ArticleText'].tolist()[0]):
    curr = int(re.findall(r'\d+', i.group(0))[0])
    if curr>prev:
        rec_idx.append(i.span()[0])
        prev = curr
# ignore the match that has occured before

# index for recommendation
va_idx = []
prev = 0
for i in re.finditer(r'\ndiscussion ', recommd[recommd['Year'] == 2007]['ArticleText'].tolist()[0]):
    va_idx.append(i.span()[0])

# %%
print(len(rec_idx))
print(len(va_idx))
# Out:
# 13
# 13

# %%
rec_str = []
recommd2007 = recommd[recommd['Year'] == 2007]['ArticleText'].tolist()[0]
for i in range(len(rec_idx)):
    rec_str.append(recommd2007[rec_idx[i]:va_idx[i]])
    
recommd.loc[recommd['Year'] == 2007, 'ArticleText'] = ''.join(rec_str)

# %%
# filter out invalid recommendations
recommd = recommd[[i[0] not in [94, 113] for i in recommd['PageNumber']]]
recommd = recommd[[len(i)>5 for i in recommd['ArticleText']]]

# %%
recommd.head()
# Out:
#    ArticleIndex                                      Title  \
# 0             8                            recommendations
# 1            23                            recommendations
# 3            39                            recommendations
# 6            61                            recommendations
# 7            68  status of previous report recommendations
#
#                                          ArticleText  \
# 0  based on the its research, collaboration, part...
# 1  the full committee recommends that the secreta...
# 3  \n1. initiate a review of the funding and oper...
# 6  overview \n\nthe committee decided to request ...
# 7  \noverview \n\nthe committee decided to reques...
#
#                      PageNumber  Year
# 0                  [17, 18, 19]  1996
# 1  [67, 68, 69, 70, 71, 72, 73]  1997
# 3                 [98, 99, 100]  1998
# 6     [140, 141, 142, 143, 144]  1999
# 7          [166, 167, 168, 169]  2000

# %%
articleDF = recommd.sort_values(['Year'])
articleDF.head()
# Out:
#    ArticleIndex                                      Title  \
# 0             8                            recommendations
# 1            23                            recommendations
# 3            39                            recommendations
# 6            61                            recommendations
# 7            68  status of previous report recommendations
#
#                                          ArticleText  \
# 0  based on the its research, collaboration, part...
# 1  the full committee recommends that the secreta...
# 3  \n1. initiate a review of the funding and oper...
# 6  overview \n\nthe committee decided to request ...
# 7  \noverview \n\nthe committee decided to reques...
#
#                      PageNumber  Year
# 0                  [17, 18, 19]  1996
# 1  [67, 68, 69, 70, 71, 72, 73]  1997
# 3                 [98, 99, 100]  1998
# 6     [140, 141, 142, 143, 144]  1999
# 7          [166, 167, 168, 169]  2000

# %%
def get_recomd_start_idx(text):
    rec_idx = []
    prev = 0
    for i in re.finditer(r'(recommendation \d+ |\n\d+\. |\nnumber \d+\. )', text):
        curr = int(re.findall(r'\d+', i.group(0))[0])
        if curr>prev:
            rec_idx.append(i.span()[0])
            prev = curr
    return rec_idx

# %%
recommds_list = {}
for y in articleDF['Year'].unique():
    recText = []
    text = articleDF[articleDF['Year'] == y]['ArticleText'].tolist()[0]
    ri = get_recomd_start_idx(text)
    ri.append(len(text))
    for i in range(len(ri)-1):
        recText.append(text[ri[i]:ri[i+1]])
    recommds_list[y] = recText

# %%
# get the number of sub lists for each recommendation article
print([f'{key}: {len(val)}' for key, val in recommds_list.items()])
# Out:
# ['1996: 16', '1997: 62', '1998: 10', '1999: 4', '2000: 1', '2001: 5', '2002: 4', '2004: 5', '2005: 9', '2006: 10', '2007: 13', '2008: 22', '2009: 14', '2011: 13', '2012: 11', '2013: 5', '2014: 6', '2015: 4', '2016: 3', '2017: 4', '2018: 4', '2020: 4']

# %%
# capture recommendation lists in 1999
def get_recomd_1999():
    text = articleDF[articleDF['Year'] == 1999]['ArticleText'].tolist()[0]
    rec_idx = []
    prev = 0
    for i in re.finditer(r'\nnumber \d+\.', text):
        curr = int(re.findall(r'\d+', i.group(0))[0])
        if curr>prev:
            rec_idx.append(i.span()[0])
            prev = curr
    recText = []
    rec_idx.append(len(text))
    for i in range(len(rec_idx)-1):
        recText.append(text[rec_idx[i]:rec_idx[i+1]])
    return recText
recommds_list[1999] = get_recomd_1999()

# %%
# capture recommendation lists in 2000
def get_recomd_2000():
    text = articleDF[articleDF['Year'] == 2000]['ArticleText'].tolist()[0]
    rec_idx = []
#     prev = 0
    for i in re.finditer(r'(\nnumber ?(\d+)?\.?|\nrecommends that)', text):
#         curr = int(re.findall(r'\d+', i.group(0))[0])
#         if curr>prev:
        rec_idx.append(i.span()[0])
#             prev = curr
    recText = []
    rec_idx.append(len(text))
    for i in range(len(rec_idx)-1):
        recText.append(text[rec_idx[i]:rec_idx[i+1]])
    return recText
recommds_list[2000] = get_recomd_2000()
# get_recomd_2000()

# %%
# capture recommendation lists in 2002
def get_recomd_2002():
    text = articleDF[articleDF['Year'] == 2002]['ArticleText'].tolist()[0]
    rec_idx = []
#     prev = 0
    for i in re.finditer(r'\n\d+\.', text):
#         curr = int(re.findall(r'\d+', i.group(0))[0])
#         if curr>prev:
        rec_idx.append(i.span()[0])
#             prev = curr
    recText = []
    rec_idx.append(len(text))
    for i in range(len(rec_idx)-1):
        recText.append(text[rec_idx[i]:rec_idx[i+1]])
    return recText
recommds_list[2002] = get_recomd_2002()

# %%
# check again
print([f'{key}: {len(val)}' for key, val in recommds_list.items()])
# Out:
# ['1996: 16', '1997: 62', '1998: 10', '1999: 14', '2000: 15', '2001: 5', '2002: 10', '2004: 5', '2005: 9', '2006: 10', '2007: 13', '2008: 22', '2009: 14', '2011: 13', '2012: 11', '2013: 5', '2014: 6', '2015: 4', '2016: 3', '2017: 4', '2018: 4', '2020: 4']

# %%
# recommds_list

# %%
# spell correction

for key in recommds_list:
    val = [remove_extra_space(remove_new_line(i)).split(' ') for i in recommds_list[key]]
    corrected = []
    for v in val:
        recommdCrcted = ' '.join([sym_spell.lookup(t, Verbosity.CLOSEST, max_edit_distance=2, include_unknown=True, ignore_token=r"(\w+\d|\W|\d|va|\w+\W)")[0].term for t in v if t!= ''])
        if recommdCrcted.strip()[-1] != '.':
             recommdCrcted += '.'
        corrected.append(recommdCrcted)
                
    recommds_list[key] = corrected

# %%
recommds_list[1996]
# Out:
# ['1. establish a separate budget line item for the advisory committee on minonty veterans.',
#  '2. appropriate 125,000.00 for the fiscal year year budget for the advisory committee on minority veterans.',
#  '3. recognize the appropnate regional and national minority organizations that serve our countrys diverse population proups and invite them as genuine partners, consultants, advisors and expert witnesses in enriching the departments commitment to serve the needs of our minomty veterans.',
#  '4. authonze an assessment be conducted and a report submitted in fy 97 by the department of veterans affairs to determine the validity of the commuttees concern regarding ethnic representation on the rating panels and the ment review boards, as well as among the counselors who advise our minority veteran populations.',
#  '5. establish and fund an intra agency task force, chaired by the director of the center for minonty veterans, to conduct a needs assessment for health care, benefits and compensation research of all our minonty veterans by ethnic groups and submit a report by monthyear,.',
#  '6. instruct the under secretary for health and the under secretary for benefits restructure their organizations internal minority advisory panels to mirror that of the federal advisory committee on minority veterans.',
#  '7. direct ethnic identifiers be included immediately on all appropnate department arpiicauion forms, particulariv the ital application form completed by ail veterans, and be correlated with department of defense manpower files and the revisions to the office of \\fanavement and budget directive 15.',
#  '8. direct the director. center for minonty veterans, to establish a secretarys task force by month year to assess and recommend changes to current va cultural sensitivity policy and programs for implementation immediately upon approval of the secretary of veterans affairs. 16.',
#  '9. authorize and fund a five member minonty veterans review commission mvrc , chaired by the chairman, advisory committee on minority veterans, with consultative authority and staff support, to conduct a senes of focus meetings with minority veterans and organizations across the country, to include the pacific, to determine the blueprint of needs and concerns, as well as recommendations, of all our minonty veterans and followed by a conference on the west coast, in the midwest. and on the east coast to report the findings to our minority veterans. their report would be presented to you for concurrence and advocacy by 1monthyear.',
#  '10. charge the under secretary for health to take the lead in forming and funding a reassessment panel, cochaired by the director, center for minority veterans and including two members of the advisory committee on minority veterans, to review all programs for homeless minonty veterans and drug alcohol treatment for minority veterans with the purpose to implement effective, culturally appropriate, coherent and networked programs and policies by monthyear. their report would be included in our committees fiscal year year report.',
#  '11. inform the under secretary for health to establish a minority health review panel, cochaired by a member of the advisory committee on minority veterans, to collaborate with the bureau of primary health care, health resources and administration agency, and others in determining and tmplementing the best models for health care delivery system for minority veterans, to include native alternative healing methods. their report would be made a part of our committees fiscal year year report.',
#  '12. request the united states congress take action to make permanent the advisory commuttee on minority veterans.',
#  '13. submut a formal request to the congress to change the expiration date of public law 102 547, native american veterans direct home loan program, from its current expirauon date of year to a permanent benefit without expiration.',
#  '14. establish an immediate department policy that accepts without qualification the reports or evaluations by the indian health service regarding establishment of benefit anu compensation claims, including the onginal clam. if necessary, seek amendment to puchic law 103 146, section 5125.',
#  '15. submit a request to congress to amend section 2408 of 38 u.s.c. to permit mogi vovermments, the government of amencan samoa, the government of guam and ine statuloriv recogmzed native hawatian government to be eligible for grants in aid for _ the purpose of establishing, expanding, or improving veterans cemeteries.',
#  '16. approve the addition of three full time staff members to the center for \\iinonty veterans effective monthyear and the funding to establish a worldwide web sive tor the center immediately. 17 annex a,.']

# %%
# save recommds_list as a dataframe
recommdSents = pd.DataFrame({'Year': [i for i in recommds_list],
                            'Recommendations': [remove_extra_space(remove_backslash(remove_new_line('&&'.join(i)))) for i in recommds_list.values()]})

# %%
recommdSents.to_csv('CMV_Reports_Article_Recommendations_lists.csv')
